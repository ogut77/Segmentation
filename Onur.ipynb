# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/Segmentation/blob/master/Onur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import urllib.request


for x in range(2009, 2018):
    data=str(x)+".csv"
    url = "http://data.europa.eu/euodp/repository/ec/dg-grow/mapps/TED_CAN_"+data
    print(url)
    dt=urllib.request.urlretrieve(url,'/content/drive/My Drive/'+data)
# Out:
# http://data.europa.eu/euodp/repository/ec/dg-grow/mapps/TED_CAN_2009.csv

# %%
# !ls '/content/drive/My Drive/'
# Out:
#  2009.csv   2012.csv   2015.csv  'Colab Notebooks'   shakespeare.txt
#  2010.csv   2013.csv   2016.csv   ml-latesta
#  2011.csv   2014.csv   2017.csv   ml-latest-smalla

# %%
d2009=pd.read_csv('/content/drive/My Drive/2009.csv')
d2009.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (27,48,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID_NOTICE_CAN                                     TED_NOTICE_URL  YEAR  \
# 0     2009182880  ted.europa.eu/udl?uri=TED:NOTICE:182880-2009:T...  2009
# 1     2009182880  ted.europa.eu/udl?uri=TED:NOTICE:182880-2009:T...  2009
# 2     2009182880  ted.europa.eu/udl?uri=TED:NOTICE:182880-2009:T...  2009
# 3     2009182880  ted.europa.eu/udl?uri=TED:NOTICE:182880-2009:T...  2009
# 4     2009182880  ted.europa.eu/udl?uri=TED:NOTICE:182880-2009:T...  2009
#
#    ID_TYPE DT_DISPATCH XSD_VERSION  CANCELLED  CORRECTIONS  B_MULTIPLE_CAE  \
# 0        3   02-JUL-09        D205          0            0             NaN
# 1        3   02-JUL-09        D205          0            0             NaN
# ...

# %%
d2009.count()
# Out:
# ID_NOTICE_CAN                   398527
# TED_NOTICE_URL                  398527
# YEAR                            398527
# ID_TYPE                         398527
# DT_DISPATCH                     398527
# XSD_VERSION                     398527
# CANCELLED                       398527
# CORRECTIONS                     398527
# B_MULTIPLE_CAE                       0
# CAE_NAME                        398527
# CAE_NATIONALID                       0
# CAE_ADDRESS                     395742
# CAE_TOWN                        398527
# CAE_POSTAL_CODE                 396358
# ISO_COUNTRY_CODE                398527
# B_MULTIPLE_COUNTRY                   0
# ISO_COUNTRY_CODE_ALL                 0
# CAE_TYPE                        398527
# EU_INST_CODE                         0
# MAIN_ACTIVITY                   294538
# B_ON_BEHALF                     291108
# B_INVOLVES_JOINT_PROCUREMENT         0
# B_AWARDED_BY_CENTRAL_BODY            0
# TYPE_OF_CONTRACT                398527
# ...

# %%
dt2009=d2009[['ID_NOTICE_CAN','YEAR','CANCELLED','CAE_TOWN','ISO_COUNTRY_CODE' ,'CAE_TYPE', 'TYPE_OF_CONTRACT'  ,'CPV', 'B_GPA',
              'VALUE_EURO', 'VALUE_EURO_FIN_1', 'VALUE_EURO_FIN_2', 'B_EU_FUNDS', 'TOP_TYPE', 'B_ACCELERATED' ,'CRIT_CODE',
              'B_ELECTRONIC_AUCTION', 'ID_AWARD', 'WIN_TOWN', 'WIN_COUNTRY_CODE' ,'NUMBER_OFFERS','AWARD_EST_VALUE_EURO', 'AWARD_VALUE_EURO',
              'AWARD_VALUE_EURO_FIN_1', 'B_SUBCONTRACTED', 'DT_AWARD']]

# %%
dt2009.head()
# Out:
#    ID_NOTICE_CAN  YEAR  CANCELLED CAE_TOWN ISO_COUNTRY_CODE CAE_TYPE  \
# 0     2009182880  2009          0  Chęciny               PL        6
# 1     2009182880  2009          0  Chęciny               PL        6
# 2     2009182880  2009          0  Chęciny               PL        6
# 3     2009182880  2009          0  Chęciny               PL        6
# 4     2009182880  2009          0  Chęciny               PL        6
#
#   TYPE_OF_CONTRACT         CPV B_GPA  VALUE_EURO    ...      \
# 0                U  33141000.0     N   302510.35    ...
# 1                U  33141000.0     N   302510.35    ...
# 2                U  33141000.0     N   302510.35    ...
# 3                U  33141000.0     N   302510.35    ...
# 4                U  33141000.0     N   302510.35    ...
#
#    B_ELECTRONIC_AUCTION   ID_AWARD  WIN_TOWN WIN_COUNTRY_CODE NUMBER_OFFERS  \
# 0                     N  2923083.0      Łódź              NaN           1.0
# ...

# %%
#drop cancelled b_eu_funds b_accelerated crit_code b_electronic_auction cae_town win_town b_subcontracted
tempDF = tempDF.drop(columns=['CANCELLED','B_EU_FUNDS','B_ACCELERATED','CRIT_CODE',
              'B_ELECTRONIC_AUCTION'])
